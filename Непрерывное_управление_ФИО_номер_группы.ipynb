# %% [markdown]
# # Управление с непрерывными действиями (Continuous Control) (<span style="color: green">10 баллов за основную часть + 5 баллов за бонусную часть</span>)
#
# #### Дедлайн (жёсткий) задания: 26.04.2026,  UTC+3.
#
# #### При сдаче задания нужно  поместить в архив данный файл и папки с логами и видео, сохраняя относительные пути, и послать архив в систему сдачи.
#
# ### <span style="color: red"> Если работа была списана и/или сделана LLM, то за работу ставится 0 баллов. </span>

# %% [markdown]
# # Работа выполнена: ФИО, номер группы.

# %% [markdown]
# В этом домашнем задании предлагается решить задачу управления с непрерывными действиями, используя алгоритмы:
#
# - **Twin Delayed DDPG (TD3)** (**Раздел 6.1.6 (Алгоритм 23)**)
# - **Soft Actor-Critic (SAC)** (**Раздел 6.2.4 (Алгоритм 24)**)
#
# Оба алгоритма являются off-policy и считаются одними из наиболее эффективных для задач управления в непрерывном пространстве действий. Они основаны на базовом алгоритме **Deep Deterministic Policy Gradient (DDPG)** (**Раздел 6.1.5 (Алгоритм 22)**), который можно представить как "DQN с отдельной нейросетью для аппроксимации жадной политики". Основные отличия заключаются в различных стабилизационных приёмах:
#
# - TD3 обучает детерминированную политику, тогда как SAC использует стохастическую политику. Это означает, что в SAC достаточно просто сэмплировать действия из политики для исследования, в то время как в TD3 необходимо вручную добавлять шум к действиям.
# - TD3 добавляет к действиям обрезанный шум (clipped noise) при расчёте целевых значений, что помогает бороться с переоценкой. SAC использует формализм максимальной энтропии и добавляет бонус за энтропию в функцию ценности, поощряя более разнообразные действия.

# %%
import numpy as np
import matplotlib.pyplot as plt
from tqdm.auto import trange
from queue import deque
from pathlib import Path
from IPython.display import HTML

import gymnasium as gym
from gymnasium.wrappers import RecordVideo

import torch
import torch.nn as nn
from torch.distributions import Normal

from logger import TensorboardSummaries as Summaries

# %%
DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
DEVICE
# Out:
# 'cpu'

# %% [markdown]
# ## Среда

# %% [markdown]
# Сначала мы создадим экземпляр среды.

# %%
env = gym.make("BipedalWalker-v3", render_mode="rgb_array")

env.reset()

state_dim = env.observation_space.shape[0]
action_dim = env.action_space.shape[0]

print("Размерность вектора состояний dim =", state_dim)
print("n_actions =", action_dim)
# Out:
# Размерность вектора состояний dim = 24
# n_actions = 4
# /Users/daeron/miniconda3/envs/mujoco/lib/python3.10/site-packages/pygame/pkgdata.py:25: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import resource_stream, resource_exists

# %% [markdown]
# Посмотрим на среду.

# %%
plt.imshow(env.render());

# %% [markdown]
# Давайте посмотрим на случайную политику и посмотрим, как это выглядит.

# %%
class RandomActor():
    def get_action(self, states):
        assert len(states.shape) == 1, "Не работает с батчами"
        return env.action_space.sample()

# %%
s, _ = env.reset()
rewards_per_step = []
actor = RandomActor()

for i in range(10000):
    a = actor.get_action(s)
    s, r, terminated, truncated, _ = env.step(a)

    rewards_per_step.append(r)

    if terminated or truncated:
        s, _ = env.reset()
        print("done: ", i)
# Out:
# done:  58
# done:  1658
# done:  1740
# done:  1794
# done:  1855
# done:  3455
# done:  3535
# done:  3603
# done:  3671
# done:  3738
# done:  5338
# done:  5394
# done:  5457
# done:  7057
# done:  7158
# done:  7250
# done:  7351
# done:  7404
# done:  7482
# done:  9082
# done:  9145

# %% [markdown]
# В основном, каждый эпизод длится **1600 шагов** &mdash; это ограничение по времени, после которого происходит завершение эпизода. Однако иногда эпизод завершается раньше, если симуляция "понимает", что агент, например, **упал** или **разбился** &mdash; то есть ситуация явно неудачная для продолжения.

# %% [markdown]
# Посмотрим, что мы получаем при использовании случайной политики.

# %%
def evaluate(env, actor, n_games=1, t_max=1600):
    '''
    Запускает n_games эпизодов и возвращает массив наград.
    
    Возвращает
    -------
    rewards: np.array
        Массив наград
    '''
    rewards = []

    for _ in range(n_games):
        s, _ = env.reset()
        R = 0

        for _ in range(t_max):
            
            ### Ваш код
            action = actor.get_action(s)
            ###

            assert (action.max() <= 1).all() and  (action.min() >= -1).all()

            s, r, terminated, truncated, _ = env.step(action)

            R += r

            if terminated or truncated:
                break

        rewards.append(R)

    return np.array(rewards)

# %%
# !pip install moviepy
# Out:
# Collecting moviepy
#   Using cached moviepy-2.2.1-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: decorator<6.0,>=4.0.2 in /Users/daeron/miniconda3/envs/mujoco/lib/python3.10/site-packages (from moviepy) (5.2.1)
# Requirement already satisfied: imageio<3.0,>=2.5 in /Users/daeron/miniconda3/envs/mujoco/lib/python3.10/site-packages (from moviepy) (2.37.3)
# Collecting imageio_ffmpeg>=0.2.0 (from moviepy)
#   Using cached imageio_ffmpeg-0.6.0-py3-none-macosx_11_0_arm64.whl.metadata (1.5 kB)
# Requirement already satisfied: numpy>=1.25.0 in /Users/daeron/miniconda3/envs/mujoco/lib/python3.10/site-packages (from moviepy) (2.2.6)
# Collecting proglog<=1.0.0 (from moviepy)
#   Using cached proglog-0.1.12-py3-none-any.whl.metadata (794 bytes)
# Collecting python-dotenv>=0.10 (from moviepy)
#   Using cached python_dotenv-1.2.2-py3-none-any.whl.metadata (27 kB)
# Collecting pillow<12.0,>=9.2.0 (from moviepy)
#   Downloading pillow-11.3.0-cp310-cp310-macosx_11_0_arm64.whl.metadata (9.0 kB)
# Requirement already satisfied: tqdm in /Users/daeron/miniconda3/envs/mujoco/lib/python3.10/site-packages (from proglog<=1.0.0->moviepy) (4.67.3)
# Using cached moviepy-2.2.1-py3-none-any.whl (129 kB)
# Downloading pillow-11.3.0-cp310-cp310-macosx_11_0_arm64.whl (4.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 1.5 MB/s  0:00:03 eta 0:00:01
# Using cached proglog-0.1.12-py3-none-any.whl (6.3 kB)
# Using cached imageio_ffmpeg-0.6.0-py3-none-macosx_11_0_arm64.whl (21.1 MB)
# Using cached python_dotenv-1.2.2-py3-none-any.whl (22 kB)
# Installing collected packages: python-dotenv, proglog, pillow, imageio_ffmpeg, moviepy
#   Attempting uninstall: pillow
#     Found existing installation: pillow 12.0.0
#     Uninstalling pillow-12.0.0:
#       Successfully uninstalled pillow-12.0.0
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5/5 [moviepy]m3/5 [imageio_ffmpeg]
# Successfully installed imageio_ffmpeg-0.6.0 moviepy-2.2.1 pillow-11.3.0 proglog-0.1.12 python-dotenv-1.2.2

# %%
with RecordVideo(
    env = gym.make("BipedalWalker-v3", render_mode="rgb_array"),
    video_folder="./videos_test"
) as env_monitor:
    evaluate(env_monitor, actor, n_games=1, t_max=300)

# %%
video_paths = sorted([s for s in Path('videos_test').iterdir() if s.suffix == '.mp4'])
video_path = video_paths[-1]

data_url = str(video_path)

HTML("""
<video width="640" height="480" controls>
  <source src="{}" type="video/mp4">
</video>
""".format(data_url))
# Out:
# <video width="640" height="480" controls>
#   <source src="videos_test/rl-video-episode-0.mp4" type="video/mp4">
# </video>

# %% [markdown]
# # Буфер

# %% [markdown]
# То же самое, что и в DQN. Вы можете просто скопировать код из вашего задания по DQN.
#
# #### Напомним интерфейс:
# * `exp_replay.add(obs, act, rw, next_obs, done)`  &mdash; сохраняет кортеж (s,a,r,s',done) в буфер.
# * `exp_replay.sample(batch_size)` &mdash; возвращает наблюдения, действия, награды, следующие наблюдения и is_done для `batch_size` случайных сэмплов.
# * `len(exp_replay)` &mdash; возвращает количество элементов, хранящихся в буфере на данный момент.

# %%
class ReplayBuffer(object):
    def __init__(self, size):
        """
        Создаёт буфер реплеев.
        """
        self._storage = deque(maxlen=size)
        self._maxsize = size

    def __len__(self):
        return len(self._storage)

    def add_random(self, obs_t, action, reward, obs_tp1, done):
        '''
        Убедитесь, что _storage не превзойдёт по размерам _maxsize.
        Убедитесь, что FIFO правило выполняется: старейшие прецеденты должны удаляться раньше всех.
        '''
        data = (obs_t, action, reward, obs_tp1, done)
        self._storage.append(data)

    def sample_random(self, batch_size):
        """
        Сэмплирование батча переходов.
            
        Возвращает
        -------
        obs_batch: np.array
            батч наблюдений (состояний)
        act_batch: np.array
            батч действий, выполненных на основе obs_batch
        rew_batch: np.array
            награды, полученные в качестве результата выполнения act_batch
        next_obs_batch: np.array
            следующие наблюдения (состояния), полученные после выполнения act_batch
        done_mask: np.array
            done_mask[i] = 1, если выполнение act_batch[i] повлекло
            окончание эпизода и 0 иначе.
        """

        ### Ваше решение
        idxes = np.random.randint(0, len(self._storage), size=batch_size)
        ###
        
        ### Ваше решение
        sample = list(zip(*[self._storage[i] for i in idxes]))
        ###

        return (np.array(sample[0]), np.array(sample[1]), np.array(sample[2]), np.array(sample[3]), np.array(sample[4]))

# %% [markdown]
# Протестим.

# %%
exp_replay = ReplayBuffer(10)

for _ in range(30):
    exp_replay.add_random(env.reset()[0], env.action_space.sample(), 1.0, env.reset()[0], done=False)

obs_batch, act_batch, reward_batch, next_obs_batch, is_done_batch = exp_replay.sample_random(5)

assert len(exp_replay) == 10, "Размер буфера должен быть равен 10, потому что это максимальная вместимость"

# %% [markdown]
# Функция для записи в буфер.

# %%
def play_and_record(initial_state, agent, env, exp_replay, n_steps=1):
    """
    Играется в среде ровно n шагов и записывается каждая пятёрка (s, a, r, s', done) в буффер.

    Возвращает
    -------
        sum_rewards: float
            суммарную награду за n шагов.
        s: float
            состояние, в котором осталась среда.
    """
    s = initial_state
    sum_rewards = 0

    for t in range(n_steps):
        
        ### Ваш код
        a = agent.get_action(s)
        ###
        
        ns, r, terminated, truncated, _ = env.step(a)
        
        exp_replay.add_random(s, a, r, ns, terminated)
        
        s = env.reset()[0] if terminated or truncated else ns
        
        sum_rewards += r        

    return sum_rewards, s

# %% [markdown]
# # Критик

# %% [markdown]
# Давайте начнём с модели критика &mdash; она одинаковая для **TD3** и **SAC**. С одной стороны, он будет приближать оптимальную функцию $Q^*(s, a)$, а с другой &mdash; оценивать текущего актора $\pi$, то есть рассматриваться как
# $Q^{\pi}(s, a)$. Этот критик принимает на вход как состояние $s$, так и действие $a,$ а на выходе выдаёт скалярное значение.
#
# Важно: если модель возвращает скаляр на выходе, хорошей практикой является применение .squeeze(), чтобы избежать неожиданного broadcast-а, поскольку тензор формы [batch_size, 1] может автоматически расширяться при операциях с другими тензорами.
#
# Рекомендуемая архитектура &mdash; полносвязная нейронная сеть (MLP) с тремя слоями.

# %% [markdown]
# <span style="color: green"> __(1 балл)__ </span>

# %%
class Critic(nn.Module):
    def __init__(self, state_dim, action_dim, hidden_dim=256):
        super().__init__()  
        
        ### Ваш код
        self.net = nn.Sequential(
            nn.Linear(state_dim + action_dim, hidden_dim),
            nn.ReLU(),
            nn.Linear(hidden_dim, hidden_dim),
            nn.ReLU(),
            nn.Linear(hidden_dim, 1),
        )
        ###
        
    def forward(self, states, actions):
    
        ### Ваш код
        x = torch.cat([states, actions], dim=-1)
        output = self.net(x).squeeze(-1)
        ###

        return output

    def get_qvalues(self, states, actions):
        '''
        Возвращает qvalues
        
        Параметры
        ----------
        states: torch.tensor [batch_size x features]
        actions: torch.tensor [batch_size x actions_dim]
            
        Возвращает
        -------
        qvalues: torch.tensor [batch_size]
        '''
        ### Ваш код
        qvalues = self.forward(states, actions)
        ###

        assert len(qvalues.shape) == 1 and qvalues.shape[0] == states.shape[0]
        
        return qvalues

# %% [markdown]
# # TD3

# %%
env = gym.make("BipedalWalker-v3", render_mode="rgb_array")
env = Summaries(env, "TD3")

# %% [markdown]
# Определим политику, или актора $\pi$. Необходимо смоделировать детерминированную политику. То есть, модель должна возвращать `action_dim` чисел в диапазоне $[-1, 1]$. К сожалению, детерминированные политики могут вызывать проблемы со стабильностью и исследованием, поэтому нам потребуется реализовать три "режима" работы этой политики:
#
# 1. Первый режим &mdash; **жадный** &mdash; это просто прямой проход через сеть. Он будет использоваться для обучения актора.
# 2. Второй режим &mdash; **режим исследования** &mdash; когда нужно добавить шум (например, гауссовский), чтобы собирать более разнообразные данные.
# 3. Третий режим &mdash; **"обрезанный шум"** &mdash; используется при расчёте целевого значения для критика. Здесь мы хотим добавить шум к выходу актора, но не слишком сильный, поэтому используем обрезанный шум:
# $$\pi_{\theta}(s) + \varepsilon, \quad \varepsilon = \operatorname{clip}(\epsilon, -0.5, 0.5), \quad \epsilon \sim \mathcal{N}(0, \sigma^2 I)$$
#
# Рекомендуемая архитектура &mdash; полносвязная нейросеть (MLP) с тремя слоями.

# %% [markdown]
# <span style="color: green"> __(2 балла)__ </span>

# %%
class TD3_Actor(nn.Module):
    def __init__(self, state_dim, action_dim, device, hidden_dim=256):
        super().__init__() 
        self.device = device
        
        ### Ваш код
        self.net = nn.Sequential(
            nn.Linear(state_dim, hidden_dim),
            nn.ReLU(),
            nn.Linear(hidden_dim, hidden_dim),
            nn.ReLU(),
            nn.Linear(hidden_dim, action_dim),
            nn.Tanh(),
        )
        ###
        
    def forward(self, state):
        ### Ваш код
        output = self.net(state)
        ###
        return output
    
    def get_best_action(self, states):
        '''
        Используется для оптимизации актора.
        Требуется, чтобы действия были дифференцируемыми по параметрам модели.
        
        Параметры
        ----------
        states: torch.tensor [batch_size x features]
            
        Возвращает
        -------
        actions: torch.tensor [batch_size x actions_dim]
        '''
        ### Ваш код
        actions = self.forward(states)
        ###

        return actions
        
    def get_action(self, states, std_noise=0.1):
        '''
        Используется для взаимодействия с окружающей средой и сбора данных.
        Поэтому к действиям необходимо добавлять шум.
        
        Параметры
        ----------
        states: np.array [batch_size x features]
        std_noise: float
        
        Возвращает
        -------
        actions: np.array [batch_size x actions_dim]
        '''
        # Градиенты тут не нужны, так как используется только для взаимодействия
        with torch.no_grad():
            
            ### Ваш код
            states = torch.tensor(states, device=self.device, dtype=torch.float)
            was_1d = len(states.shape) == 1
            if was_1d:
                states = states.unsqueeze(0)
            actions = self.forward(states)
            actions = actions + std_noise * torch.randn_like(actions)
            actions = torch.clamp(actions, -1., 1.)
            actions = actions.cpu().numpy()
            if was_1d:
                actions = actions[0]
            ###

            assert actions.max() <= 1. and actions.min() >= -1,                "Действия должны находиться в диапазоне [-1, 1]"
        return actions

    
    def get_target_action(self, states, std_noise=0.2, clip_eta=0.5):
        '''
        Используется для генерации целевых значений при обучении критика.
        Возвращает действия с добавленным "обрезанным шумом".
        
        Параметры
        ----------
        states: torch.tensor [batch_size x features]
        std_noise: float
        clip_eta: float
        
        Возвращает
        -------
        actions: torch.tensor [batch_size x actions_dim]
        '''
        # Градиенты тут также не нужны, используется только для генерации целевых значений
        with torch.no_grad():
            
            ### Ваш код
            actions = self.forward(states)
            noise = std_noise * torch.randn_like(actions)
            noise = torch.clamp(noise, -clip_eta, clip_eta)
            actions = torch.clamp(actions + noise, -1., 1.)
            ###

            assert actions.max() <= 1. and actions.min() >= -1,                "Действия должны находиться в диапазоне [-1, 1]"
        return actions

# %% [markdown]
# Протестим.

# %%
exp_replay = ReplayBuffer(2000)
actor = TD3_Actor(state_dim, action_dim, DEVICE).to(DEVICE)

state, _ = env.reset()
play_and_record(state, actor, env, exp_replay, n_steps=1000)

assert len(exp_replay) == 1000, \
    "play_and_record должен был добавить ровно 1000 шагов, но вместо этого добавил %i" % len(exp_replay)

is_dones = list(zip(*exp_replay._storage))[-1]

for _ in range(100):
    obs_batch, act_batch, reward_batch, next_obs_batch, is_done_batch = exp_replay.sample_random(10)

    assert obs_batch.shape == next_obs_batch.shape == (10,) + (state_dim,), \
        "Батчи наблюдений и следующих состояний должны иметь форму (10, %d)" % state_dim

    assert act_batch.shape == (10, action_dim), \
        "Батч действий должен иметь форму (10, 8), но вместо этого: %s" % str(act_batch.shape)

    assert reward_batch.shape == (10,), \
        "Батч наград должен иметь форму (10,), но вместо этого: %s" % str(reward_batch.shape)

    assert is_done_batch.shape == (10,), \
        "Батч is_done должен иметь форму (10,), но вместо этого: %s" % str(is_done_batch.shape)

    assert [int(i) in (0, 1) for i in is_dones], \
        "is_done должен быть строго True или False (или 1/0)"

print("Отлично!")
# Out:
# Отлично!

# %% [markdown]
# ## Инициализация

# %%
max_buffer_size = 10**5
exp_replay = ReplayBuffer(max_buffer_size)

# %%
actor = TD3_Actor(state_dim, action_dim, DEVICE).to(DEVICE)
critic1 = Critic(state_dim, action_dim).to(DEVICE)
critic2 = Critic(state_dim, action_dim).to(DEVICE)

# %% [markdown]
# Чтобы стабилизировать обучение, нам понадобятся целевые сети &mdash; медленно обновляемые копии наших моделей.

# %%
target_actor = TD3_Actor(state_dim, action_dim, DEVICE).to(DEVICE)
target_critic1 = Critic(state_dim, action_dim).to(DEVICE)
target_critic2 = Critic(state_dim, action_dim).to(DEVICE)

target_actor.load_state_dict(actor.state_dict())
target_critic1.load_state_dict(critic1.state_dict())
target_critic2.load_state_dict(critic2.state_dict());

# %% [markdown]
# В задачах с непрерывным управлением целевые сети обычно обновляются с использованием экспоненциального сглаживания:
# $$\theta^{-} \leftarrow \tau \theta + (1 - \tau) \theta^{-},$$
# где $\theta^{-}$ &mdash; веса дополнительной сети, $\theta$ &mdash; текущие параметры модели, а $\tau$ &mdash; гиперпараметр (коэффициент обновления).

# %%
def update_target_networks(model, target_model, tau=0.005):
    for param, target_param in zip(model.parameters(), target_model.parameters()):
          target_param.data.copy_(tau * param.data + (1 - tau) * target_param.data)

# %% [markdown]
# Наконец, у нас будет три отдельных процедуры оптимизации для обучения трёх моделей, так что давайте поприветствуем наших трёх Адамов:

# %%
opt_actor = torch.optim.Adam(actor.parameters(), lr=3e-4)
opt_critic1 = torch.optim.Adam(critic1.parameters(), lr=3e-4)
opt_critic2 = torch.optim.Adam(critic2.parameters(), lr=3e-4)

# %% [markdown]
# Функция для оптимизации.

# %%
def optimize(name, model, optimizer, loss, n_iterations, max_grad_norm=10):
    '''
    Выполняет один шаг оптимизации, ограничивает норму градиента значением max_grad_norm 
    и логирует всё в TensorBoard.
    '''
    loss = loss.mean()
    optimizer.zero_grad()
    loss.backward()
    grad_norm = nn.utils.clip_grad_norm_(model.parameters(), max_grad_norm)
    optimizer.step()

    env.writer.add_scalar(name, loss.item(), n_iterations)
    env.writer.add_scalar(name + "_grad_norm", grad_norm.item(), n_iterations)

# %% [markdown]
# ## Вычисление целевого значения для критика

# %% [markdown]
# Для одного сэмплированного перехода $(s, a, r, s')$ целевое значение имеет вид:
# $$y(s, a) = r + \gamma V(s').$$
# Как вычисляется $V(s')$? Формально, оценка Монте-Карло выглядит просто:
# $$V(s') \approx Q(s', a'),$$
# где $a'$ &mdash; это сэмпл из текущей политики $\pi(a' \mid s')$.
#
# Однако наш актор $\pi$ обучается выбирать такие действия $a'$, где критик выдаёт наибольшие значения, что может приводить к завышенным оценкам. Чтобы избежать этого, мы используем несколько приёмов:
#
# 1. Используем двух критиков (берём минимум из их значений):
# $$V(s') = \min_{i = 1,2} \left\{Q^{-}_i(s', a')\right\},$$
# где $a'$ &mdash; это сэмпл из целевой политики: $\pi^{-}(a' \mid s')$.
# 2. Для вычисления $a'$ используется режим с обрезанным шумом, чтобы не позволить политике эксплуатировать узкие пики в $Q$-функции.

# %% [markdown]
# <span style="color: green"> __(0.5 балла)__ </span>

# %%
def compute_critic_target(rewards, next_states, is_done, target_actor, target_critic1, target_critic2,
                          gamma=0.99):
    '''
    Подсчет loss для критика.
    
    Параметры
        ----------
        rewards: torch.tensor [batch_size]
        next_states: torch.tensor [batch_size x features]
        is_done: torch.tensor [batch_size]
        gamma: float
        
    Возвращает
        -------
        critic_target: torch.tensor [batch_size]
    '''
    with torch.no_grad():
        
        ### Ваш код
        next_actions = target_actor.get_target_action(next_states)
        target_q1 = target_critic1.get_qvalues(next_states, next_actions)
        target_q2 = target_critic2.get_qvalues(next_states, next_actions)
        next_values = torch.min(target_q1, target_q2)
        critic_target = rewards + gamma * (1 - is_done) * next_values
        ###
    
    return critic_target

# %% [markdown]
# Для обучения актора мы хотим просто максимизировать:
# $$\mathbb{E}_{a \sim \pi(a \mid s)} \left[Q(s, a)\right] \to \max_{\pi}.$$
# Так как политика детерминированная, математическое ожидание сводится к:
# $$Q(s, \pi(s)) \to \max_{\pi}.$$
#
# **Замечание:**
# Мы будем использовать `critic1` в качестве функции $Q$, которую актор будет пытаться "эксплуатировать".

# %% [markdown]
# <span style="color: green"> __(0.5 балла)__ </span>

# %%
def compute_actor_loss(states, actor, critic1):
    '''
    Подсчет loss для актора.
    
    
    Параметры
        ----------
        states: torch.tensor [batch_size x features]
        
    Возвращает
        -------
        actor_loss: torch.tensor [batch_size]
    '''
    ### Ваш код
    actions = actor.get_best_action(states)
    actor_loss = -critic1.get_qvalues(states, actions)
    ###
    
    return actor_loss

# %% [markdown]
# # Пайплайн

# %% [markdown]
# Цель &mdash; достичь в среднем хотя бы **300 награды**.

# %%
seed = 11 # Иногда может сильно не повезти
np.random.seed(seed)
torch.manual_seed(seed);

# %%
# %load_ext tensorboard
# %tensorboard --logdir logs
# Out:
#       <iframe id="tensorboard-frame-4e32b783e7c23496" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-4e32b783e7c23496");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
def run_TD3(env, exp_replay, actor, target_actor, critic1, target_critic1, critic2, target_critic2,
            max_grad_norm=10, n_iter_max=1500000, timesteps_per_epoch=1, start_timesteps = 5000,
            batch_size=128, policy_update_freq=2, gamma=0.99, tau=0.005):
    
    interaction_state, _ = env.reset()
    random_actor = RandomActor()
    
    for n_iterations in trange(0, n_iter_max, timesteps_per_epoch):
        
        if len(exp_replay) < start_timesteps:
            _, interaction_state = play_and_record(interaction_state, random_actor, env,
                                                   exp_replay, timesteps_per_epoch)
            continue

        _, interaction_state = play_and_record(interaction_state, actor, env, exp_replay, timesteps_per_epoch)

        states, actions, rewards, next_states, is_done = exp_replay.sample_random(batch_size)

        states = torch.tensor(states, device=DEVICE, dtype=torch.float)
        actions = torch.tensor(actions, device=DEVICE, dtype=torch.float)
        rewards = torch.tensor(rewards, device=DEVICE, dtype=torch.float)
        next_states = torch.tensor(next_states, device=DEVICE, dtype=torch.float)
        is_done = torch.tensor(is_done.astype('float32'), device=DEVICE, dtype=torch.float)
        
        ### Ваш код
        critic_target = compute_critic_target(rewards, next_states, is_done, target_actor, target_critic1, target_critic2, gamma)
        critic1_loss = (critic1.get_qvalues(states, actions) - critic_target) ** 2
        ###
        optimize("critic1", critic1, opt_critic1, critic1_loss, n_iterations, max_grad_norm)
        
        ### Ваш код
        critic2_loss = (critic2.get_qvalues(states, actions) - critic_target) ** 2
        ###
        optimize("critic2", critic2, opt_critic2, critic2_loss, n_iterations, max_grad_norm)

        if n_iterations % policy_update_freq == 0:
            ### Ваш код
            actor_loss = compute_actor_loss(states, actor, critic1)
            ###
            optimize("actor", actor, opt_actor, actor_loss, n_iterations, max_grad_norm)

            update_target_networks(critic1, target_critic1, tau)
            update_target_networks(critic2, target_critic2, tau)
            update_target_networks(actor, target_actor, tau)

# %%
# !conda activate mujoco
# !pip install -U ipywidgets jupyter tqdm
# Out:
# CondaError: Run 'conda init' before 'conda activate'
#
# Requirement already satisfied: ipywidgets in /Users/daeron/miniconda3/envs/mujoco/lib/python3.10/site-packages (8.1.8)
# Requirement already satisfied: jupyter in /Users/daeron/miniconda3/envs/mujoco/lib/python3.10/site-packages (1.1.1)
# Requirement already satisfied: tqdm in /Users/daeron/miniconda3/envs/mujoco/lib/python3.10/site-packages (4.67.3)
# Requirement already satisfied: comm>=0.1.3 in /Users/daeron/miniconda3/envs/mujoco/lib/python3.10/site-packages (from ipywidgets) (0.2.3)
# Requirement already satisfied: ipython>=6.1.0 in /Users/daeron/miniconda3/envs/mujoco/lib/python3.10/site-packages (from ipywidgets) (8.37.0)
# Requirement already satisfied: traitlets>=4.3.1 in /Users/daeron/miniconda3/envs/mujoco/lib/python3.10/site-packages (from ipywidgets) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in /Users/daeron/miniconda3/envs/mujoco/lib/python3.10/site-packages (from ipywidgets) (4.0.15)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in /Users/daeron/miniconda3/envs/mujoco/lib/python3.10/site-packages (from ipywidgets) (3.0.16)
# Requirement already satisfied: notebook in /Users/daeron/miniconda3/envs/mujoco/lib/python3.10/site-packages (from jupyter) (7.5.5)
# Requirement already satisfied: jupyter-console in /Users/daeron/miniconda3/envs/mujoco/lib/python3.10/site-packages (from jupyter) (6.6.3)
# Requirement already satisfied: nbconvert in /Users/daeron/miniconda3/envs/mujoco/lib/python3.10/site-packages (from jupyter) (7.17.0)
# Requirement already satisfied: ipykernel in /Users/daeron/miniconda3/envs/mujoco/lib/python3.10/site-packages (from jupyter) (7.1.0)
# Requirement already satisfied: jupyterlab in /Users/daeron/miniconda3/envs/mujoco/lib/python3.10/site-packages (from jupyter) (4.5.6)
# Requirement already satisfied: decorator in /Users/daeron/miniconda3/envs/mujoco/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (5.2.1)
# Requirement already satisfied: exceptiongroup in /Users/daeron/miniconda3/envs/mujoco/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (1.3.1)
# Requirement already satisfied: jedi>=0.16 in /Users/daeron/miniconda3/envs/mujoco/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.19.2)
# Requirement already satisfied: matplotlib-inline in /Users/daeron/miniconda3/envs/mujoco/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.2.1)
# Requirement already satisfied: pexpect>4.3 in /Users/daeron/miniconda3/envs/mujoco/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /Users/daeron/miniconda3/envs/mujoco/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (3.0.52)
# Requirement already satisfied: pygments>=2.4.0 in /Users/daeron/miniconda3/envs/mujoco/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (2.19.2)
# Requirement already satisfied: stack_data in /Users/daeron/miniconda3/envs/mujoco/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.6.3)
# Requirement already satisfied: typing_extensions>=4.6 in /Users/daeron/miniconda3/envs/mujoco/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (4.15.0)
# Requirement already satisfied: wcwidth in /Users/daeron/miniconda3/envs/mujoco/lib/python3.10/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets) (0.2.14)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /Users/daeron/miniconda3/envs/mujoco/lib/python3.10/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.5)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/daeron/miniconda3/envs/mujoco/lib/python3.10/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets) (0.7.0)
# Requirement already satisfied: appnope>=0.1.2 in /Users/daeron/miniconda3/envs/mujoco/lib/python3.10/site-packages (from ipykernel->jupyter) (0.1.4)
# Requirement already satisfied: debugpy>=1.6.5 in /Users/daeron/miniconda3/envs/mujoco/lib/python3.10/site-packages (from ipykernel->jupyter) (1.8.16)
# Requirement already satisfied: jupyter-client>=8.0.0 in /Users/daeron/miniconda3/envs/mujoco/lib/python3.10/site-packages (from ipykernel->jupyter) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /Users/daeron/miniconda3/envs/mujoco/lib/python3.10/site-packages (from ipykernel->jupyter) (5.9.1)
# Requirement already satisfied: nest-asyncio>=1.4 in /Users/daeron/miniconda3/envs/mujoco/lib/python3.10/site-packages (from ipykernel->jupyter) (1.6.0)
# Requirement already satisfied: packaging>=22 in /Users/daeron/miniconda3/envs/mujoco/lib/python3.10/site-packages (from ipykernel->jupyter) (25.0)
# Requirement already satisfied: psutil>=5.7 in /Users/daeron/miniconda3/envs/mujoco/lib/python3.10/site-packages (from ipykernel->jupyter) (7.0.0)
# Requirement already satisfied: pyzmq>=25 in /Users/daeron/miniconda3/envs/mujoco/lib/python3.10/site-packages (from ipykernel->jupyter) (27.1.0)
# Requirement already satisfied: tornado>=6.2 in /Users/daeron/miniconda3/envs/mujoco/lib/python3.10/site-packages (from ipykernel->jupyter) (6.5.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/daeron/miniconda3/envs/mujoco/lib/python3.10/site-packages (from jupyter-client>=8.0.0->ipykernel->jupyter) (2.9.0.post0)
# Requirement already satisfied: platformdirs>=2.5 in /Users/daeron/miniconda3/envs/mujoco/lib/python3.10/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter) (4.5.0)
# Requirement already satisfied: six>=1.5 in /Users/daeron/miniconda3/envs/mujoco/lib/python3.10/site-packages (from python-dateutil>=2.8.2->jupyter-client>=8.0.0->ipykernel->jupyter) (1.17.0)
# Requirement already satisfied: async-lru>=1.0.0 in /Users/daeron/miniconda3/envs/mujoco/lib/python3.10/site-packages (from jupyterlab->jupyter) (2.2.0)
# Requirement already satisfied: httpx<1,>=0.25.0 in /Users/daeron/miniconda3/envs/mujoco/lib/python3.10/site-packages (from jupyterlab->jupyter) (0.28.1)
# Requirement already satisfied: jinja2>=3.0.3 in /Users/daeron/miniconda3/envs/mujoco/lib/python3.10/site-packages (from jupyterlab->jupyter) (3.1.6)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in /Users/daeron/miniconda3/envs/mujoco/lib/python3.10/site-packages (from jupyterlab->jupyter) (2.3.0)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in /Users/daeron/miniconda3/envs/mujoco/lib/python3.10/site-packages (from jupyterlab->jupyter) (2.17.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.28.0 in /Users/daeron/miniconda3/envs/mujoco/lib/python3.10/site-packages (from jupyterlab->jupyter) (2.28.0)
# Requirement already satisfied: notebook-shim>=0.2 in /Users/daeron/miniconda3/envs/mujoco/lib/python3.10/site-packages (from jupyterlab->jupyter) (0.2.4)
# Requirement already satisfied: setuptools>=41.1.0 in /Users/daeron/miniconda3/envs/mujoco/lib/python3.10/site-packages (from jupyterlab->jupyter) (80.9.0)
# Requirement already satisfied: tomli>=1.2.2 in /Users/daeron/miniconda3/envs/mujoco/lib/python3.10/site-packages (from jupyterlab->jupyter) (2.4.0)
# Requirement already satisfied: anyio in /Users/daeron/miniconda3/envs/mujoco/lib/python3.10/site-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter) (4.12.1)
# Requirement already satisfied: certifi in /Users/daeron/miniconda3/envs/mujoco/lib/python3.10/site-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in /Users/daeron/miniconda3/envs/mujoco/lib/python3.10/site-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter) (1.0.9)
# Requirement already satisfied: idna in /Users/daeron/miniconda3/envs/mujoco/lib/python3.10/site-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter) (3.11)
# Requirement already satisfied: h11>=0.16 in /Users/daeron/miniconda3/envs/mujoco/lib/python3.10/site-packages (from httpcore==1.*->httpx<1,>=0.25.0->jupyterlab->jupyter) (0.16.0)
# Requirement already satisfied: argon2-cffi>=21.1 in /Users/daeron/miniconda3/envs/mujoco/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (25.1.0)
# Requirement already satisfied: jupyter-events>=0.11.0 in /Users/daeron/miniconda3/envs/mujoco/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /Users/daeron/miniconda3/envs/mujoco/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.5.4)
# Requirement already satisfied: nbformat>=5.3.0 in /Users/daeron/miniconda3/envs/mujoco/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (5.10.4)
# Requirement already satisfied: overrides>=5.0 in /Users/daeron/miniconda3/envs/mujoco/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (7.7.0)
# Requirement already satisfied: prometheus-client>=0.9 in /Users/daeron/miniconda3/envs/mujoco/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.24.1)
# Requirement already satisfied: send2trash>=1.8.2 in /Users/daeron/miniconda3/envs/mujoco/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (2.1.0)
# Requirement already satisfied: terminado>=0.8.3 in /Users/daeron/miniconda3/envs/mujoco/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in /Users/daeron/miniconda3/envs/mujoco/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.9.0)
# Requirement already satisfied: babel>=2.10 in /Users/daeron/miniconda3/envs/mujoco/lib/python3.10/site-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter) (2.18.0)
# Requirement already satisfied: json5>=0.9.0 in /Users/daeron/miniconda3/envs/mujoco/lib/python3.10/site-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter) (0.13.0)
# Requirement already satisfied: jsonschema>=4.18.0 in /Users/daeron/miniconda3/envs/mujoco/lib/python3.10/site-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter) (4.26.0)
# Requirement already satisfied: requests>=2.31 in /Users/daeron/miniconda3/envs/mujoco/lib/python3.10/site-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter) (2.32.5)
# Requirement already satisfied: argon2-cffi-bindings in /Users/daeron/miniconda3/envs/mujoco/lib/python3.10/site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (25.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/daeron/miniconda3/envs/mujoco/lib/python3.10/site-packages (from jinja2>=3.0.3->jupyterlab->jupyter) (3.0.3)
# Requirement already satisfied: attrs>=22.2.0 in /Users/daeron/miniconda3/envs/mujoco/lib/python3.10/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/daeron/miniconda3/envs/mujoco/lib/python3.10/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /Users/daeron/miniconda3/envs/mujoco/lib/python3.10/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /Users/daeron/miniconda3/envs/mujoco/lib/python3.10/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter) (0.30.0)
# Requirement already satisfied: python-json-logger>=2.0.4 in /Users/daeron/miniconda3/envs/mujoco/lib/python3.10/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (4.0.0)
# Requirement already satisfied: pyyaml>=5.3 in /Users/daeron/miniconda3/envs/mujoco/lib/python3.10/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (6.0.3)
# Requirement already satisfied: rfc3339-validator in /Users/daeron/miniconda3/envs/mujoco/lib/python3.10/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /Users/daeron/miniconda3/envs/mujoco/lib/python3.10/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.1.1)
# Requirement already satisfied: fqdn in /Users/daeron/miniconda3/envs/mujoco/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.5.1)
# Requirement already satisfied: isoduration in /Users/daeron/miniconda3/envs/mujoco/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /Users/daeron/miniconda3/envs/mujoco/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (3.0.0)
# Requirement already satisfied: rfc3987-syntax>=1.1.0 in /Users/daeron/miniconda3/envs/mujoco/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.1.0)
# Requirement already satisfied: uri-template in /Users/daeron/miniconda3/envs/mujoco/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in /Users/daeron/miniconda3/envs/mujoco/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (25.10.0)
# Requirement already satisfied: beautifulsoup4 in /Users/daeron/miniconda3/envs/mujoco/lib/python3.10/site-packages (from nbconvert->jupyter) (4.14.3)
# Requirement already satisfied: bleach!=5.0.0 in /Users/daeron/miniconda3/envs/mujoco/lib/python3.10/site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter) (6.3.0)
# Requirement already satisfied: defusedxml in /Users/daeron/miniconda3/envs/mujoco/lib/python3.10/site-packages (from nbconvert->jupyter) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /Users/daeron/miniconda3/envs/mujoco/lib/python3.10/site-packages (from nbconvert->jupyter) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in /Users/daeron/miniconda3/envs/mujoco/lib/python3.10/site-packages (from nbconvert->jupyter) (3.2.0)
# Requirement already satisfied: nbclient>=0.5.0 in /Users/daeron/miniconda3/envs/mujoco/lib/python3.10/site-packages (from nbconvert->jupyter) (0.10.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /Users/daeron/miniconda3/envs/mujoco/lib/python3.10/site-packages (from nbconvert->jupyter) (1.5.1)
# Requirement already satisfied: webencodings in /Users/daeron/miniconda3/envs/mujoco/lib/python3.10/site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert->jupyter) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /Users/daeron/miniconda3/envs/mujoco/lib/python3.10/site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter) (1.4.0)
# Requirement already satisfied: fastjsonschema>=2.15 in /Users/daeron/miniconda3/envs/mujoco/lib/python3.10/site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (2.21.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/daeron/miniconda3/envs/mujoco/lib/python3.10/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/daeron/miniconda3/envs/mujoco/lib/python3.10/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter) (2.6.3)
# Requirement already satisfied: lark>=1.2.2 in /Users/daeron/miniconda3/envs/mujoco/lib/python3.10/site-packages (from rfc3987-syntax>=1.1.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.3.1)
# Requirement already satisfied: cffi>=1.0.1 in /Users/daeron/miniconda3/envs/mujoco/lib/python3.10/site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (2.0.0)
# Requirement already satisfied: pycparser in /Users/daeron/miniconda3/envs/mujoco/lib/python3.10/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (2.23)
# Requirement already satisfied: soupsieve>=1.6.1 in /Users/daeron/miniconda3/envs/mujoco/lib/python3.10/site-packages (from beautifulsoup4->nbconvert->jupyter) (2.8.3)
# Requirement already satisfied: arrow>=0.15.0 in /Users/daeron/miniconda3/envs/mujoco/lib/python3.10/site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.4.0)
# Requirement already satisfied: tzdata in /Users/daeron/miniconda3/envs/mujoco/lib/python3.10/site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (2025.3)
# Requirement already satisfied: executing>=1.2.0 in /Users/daeron/miniconda3/envs/mujoco/lib/python3.10/site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/daeron/miniconda3/envs/mujoco/lib/python3.10/site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (3.0.1)
# Requirement already satisfied: pure_eval in /Users/daeron/miniconda3/envs/mujoco/lib/python3.10/site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (0.2.3)

# %%
run_TD3(env, exp_replay, actor, target_actor, critic1, target_critic1, critic2, target_critic2)
# Out:
# Exception ignored in: <function tqdm.__del__ at 0x12e7b85e0>
# Traceback (most recent call last):
#   File "/Users/daeron/miniconda3/envs/mujoco/lib/python3.10/site-packages/tqdm/std.py", line 1148, in __del__
#     self.close()
#   File "/Users/daeron/miniconda3/envs/mujoco/lib/python3.10/site-packages/tqdm/notebook.py", line 277, in close
#     self.disp(bar_style='danger', check_delay=False)
# AttributeError: 'tqdm_notebook' object has no attribute 'disp'
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 run_TD3(env, exp_replay, actor, target_actor, critic1, target_critic1, critic2, target_critic2)
#
# Cell In[31], line 8, in run_TD3(env, exp_replay, actor, target_actor, critic1, target_critic1, critic2, target_critic2, max_grad_norm, n_iter_max, timesteps_per_epoch, start_timesteps, batch_size, policy_update_freq, gamma, tau)
#       5 interaction_state, _ = env.reset()
#       6 random_actor = RandomActor()
# ----> 8 for n_iterations in trange(0, n_iter_max, timesteps_per_epoch):
#      10     if len(exp_replay) < start_timesteps:
#      11         _, interaction_state = play_and_record(interaction_state, random_actor, env,
#      12                                                exp_replay, timesteps_per_epoch)
#
# File ~/miniconda3/envs/mujoco/lib/python3.10/site-packages/tqdm/notebook.py:310, in tnrange(*args, **kwargs)
#     308 def tnrange(*args, **kwargs):
#     309     """Shortcut for `tqdm.notebook.tqdm(range(*args), **kwargs)`."""
# --> 310     return tqdm_notebook(range(*args), **kwargs)
#
# File ~/miniconda3/envs/mujoco/lib/python3.10/site-packages/tqdm/notebook.py:234, in tqdm_notebook.__init__(self, *args, **kwargs)
#     232 unit_scale = 1 if self.unit_scale is True else self.unit_scale or 1
#     233 total = self.total * unit_scale if self.total else self.total
# --> 234 self.container = self.status_printer(self.fp, total, self.desc, self.ncols)
#     235 self.container.pbar = proxy(self)
#     236 self.displayed = False
#
# File ~/miniconda3/envs/mujoco/lib/python3.10/site-packages/tqdm/notebook.py:108, in tqdm_notebook.status_printer(_, total, desc, ncols)
#      99 # Fallback to text bar if there's no total
#     100 # DEPRECATED: replaced with an 'info' style bar
#     101 # if not total:
#    (...)
#     105
#     106 # Prepare IPython progress bar
#     107 if IProgress is None:  # #187 #451 #558 #872
# --> 108     raise ImportError(WARN_NOIPYW)
#     109 if total:
#     110     pbar = IProgress(min=0, max=total)
#
# ImportError: IProgress not found. Please update jupyter and ipywidgets. See https://ipywidgets.readthedocs.io/en/stable/user_install.html

# %% [markdown]
# ## Оценка

# %% [markdown]
# <span style="color: green"> __(1.5 балла)__ </span>

# %%
sessions = evaluate(env, actor, n_games=20)
score = sessions.mean()
print(f"Ваша награда: {score}")

assert score >= 300, "Нужно больше учить?"
print("Отлично!")

# %% [markdown]
# ## Запись

# %%
with RecordVideo(
    env = gym.make("BipedalWalker-v3", render_mode="rgb_array"),
    video_folder="./videos_TD3"
) as env_monitor:
    evaluate(env_monitor, actor, n_games=1, t_max=300)

# %%
video_paths = sorted([s for s in Path('videos_TD3').iterdir() if s.suffix == '.mp4'])
video_path = video_paths[-1]

data_url = str(video_path)

HTML("""
<video width="640" height="480" controls>
  <source src="{}" type="video/mp4">
</video>
""".format(data_url))

# %% [markdown]
# # SAC

# %%
env = gym.make("BipedalWalker-v3", render_mode="rgb_array")
env = Summaries(env, "SAC")

# %% [markdown]
# Нужно смоделировать гауссовскую политику. Это означает, что распределение политики &mdash; это многомерное нормальное распределение с диагональной ковариационной матрицей. Должны предсказываться среднее и ковариация, при этом важно гарантировать, что ковариация остаётся неотрицательной. Пусть $f_{\theta}(s)$ &mdash; выход головы ковариации, преобразуем выход в диапазон $[-1, 1]$ с помощью `tanh`, затем спроецируем результат в интервал $[m, M]$, где $m = -20$, $M = 2$, и применим экспоненту. Это обеспечит адекватный диапазон ковариации:
# $$\sigma(s) = \exp^{m + 0.5(M - m)(\tanh(f_{\theta}(s)) + 1)}.$$
#
# Гауссовское распределение не ограничено, но нужно, чтобы действия лежали в диапазоне $[-1, 1]$. Для этого:
# 1. Моделируем неограниченное распределение:
#    $\mathcal{N}(\mu_{\theta}(s), \sigma_{\theta}(s)^2I)$
# 2. Затем каждую выборку $u$ из этого распределения преобразуем с помощью $\tanh$:
# $$u \sim \mathcal{N}(\mu, \sigma^2I)$$
# $$a = \tanh(u)$$
#
# **Важно:** После применения $\tanh$ необходимо использовать формулу замены переменных при вычислении логарифма плотности вероятности:
# $$\log p(a \mid \mu, \sigma) = \log p(u \mid \mu, \sigma) - \sum_{i = 1}^D \log \left(1 - \tanh^2(u_i)\right),$$
# где $D$ &mdash; размерность действия (`action_dim`). На практике желательно добавить небольшое значение (например, $1e{-6}$) внутрь логарифма для числовой устойчивости.

# %% [markdown]
# <span style="color: green"> __(2 балла)__ </span>

# %%
class SAC_Actor(nn.Module):
    def __init__(self, state_dim, action_dim, device, hidden_dim=256, m=-20, M=2):
        super().__init__()
        self.device = device
        
        self.m = m
        self.M = M
        
        ### Ваш код
        self.net = nn.Sequential(
            nn.Linear(state_dim, hidden_dim),
            nn.ReLU(),
            nn.Linear(hidden_dim, hidden_dim),
            nn.ReLU(),
        )
        self.mean = nn.Linear(hidden_dim, action_dim)
        self.cov = nn.Linear(hidden_dim, action_dim)
        ###
        
    def forward(self, state):
        
        ### Ваш код
        hidden = self.net(state)
        mean = self.mean(hidden)
        log_cov = self.m + 0.5 * (self.M - self.m) * (torch.tanh(self.cov(hidden)) + 1)
        cov = torch.exp(log_cov)
        ###

        return mean, cov
    
    def apply(self, states):
        '''
        Сэмплирует действия.
        
        Параметры
        ----------
            states: torch.tensor [batch_size x features]
        
        Возвращает
        -------
            actions: torch.tensor [batch_size x actions_dim]
            log_prob: torch.tensor [batch_size]
        '''
        ### Ваш код
        mean, cov = self.forward(states)
        normal = Normal(mean, cov)
        samples = normal.rsample()
        actions = torch.tanh(samples)
        log_prob = normal.log_prob(samples) - torch.log(1 - actions.pow(2) + 1e-6)
        log_prob = log_prob.sum(dim=-1)
        ###
        
        return actions, log_prob  

    def get_action(self, states):
        '''
        Используется для взаимодействия с окружающей средой и сбора данных.
        
        Параметры
        ----------
        states: np.array [batch_size x features]
        
        Возвращает
        -------
        actions: np.array [batch_size x actions_dim]
        '''
        # Градиенты тут не нужны, так как используется только для взаимодействия
        with torch.no_grad():
            
            ### Ваш код
            states = torch.tensor(states, device=self.device, dtype=torch.float)
            was_1d = len(states.shape) == 1
            if was_1d:
                states = states.unsqueeze(0)
            actions, _ = self.apply(states)
            actions = actions.cpu().numpy()
            if was_1d:
                actions = actions[0]
            ###

            assert actions.max() <= 1. and actions.min() >= -1,                "Действия должны находиться в диапазоне [-1, 1]"
        return actions

# %% [markdown]
# Протестим.

# %%
exp_replay = ReplayBuffer(2000)
actor = SAC_Actor(state_dim, action_dim, DEVICE).to(DEVICE)

state, _ = env.reset()
play_and_record(state, actor, env, exp_replay, n_steps=1000)

assert len(exp_replay) == 1000, \
    "play_and_record должен был добавить ровно 1000 шагов, но вместо этого добавил %i" % len(exp_replay)

is_dones = list(zip(*exp_replay._storage))[-1]

for _ in range(100):
    obs_batch, act_batch, reward_batch, next_obs_batch, is_done_batch = exp_replay.sample_random(10)

    assert obs_batch.shape == next_obs_batch.shape == (10,) + (state_dim,), \
        "Батчи наблюдений и следующих состояний должны иметь форму (10, %d)" % state_dim

    assert act_batch.shape == (10, action_dim), \
        "Батч действий должен иметь форму (10, 8), но вместо этого: %s" % str(act_batch.shape)

    assert reward_batch.shape == (10,), \
        "Батч наград должен иметь форму (10,), но вместо этого: %s" % str(reward_batch.shape)

    assert is_done_batch.shape == (10,), \
        "Батч is_done должен иметь форму (10,), но вместо этого: %s" % str(is_done_batch.shape)

    assert [int(i) in (0, 1) for i in is_dones], \
        "is_done должен быть строго True или False (или 1/0)"

print("Отлично!")

# %% [markdown]
# ## Инициализация

# %%
max_buffer_size = 10**5
exp_replay = ReplayBuffer(max_buffer_size)

# %%
actor = SAC_Actor(state_dim, action_dim, DEVICE).to(DEVICE)
critic1 = Critic(state_dim, action_dim).to(DEVICE)
critic2 = Critic(state_dim, action_dim).to(DEVICE)

# %%
target_critic1 = Critic(state_dim, action_dim).to(DEVICE)
target_critic2 = Critic(state_dim, action_dim).to(DEVICE)

target_critic1.load_state_dict(critic1.state_dict())
target_critic2.load_state_dict(critic2.state_dict());

# %%
opt_actor = torch.optim.Adam(actor.parameters(), lr=3e-4)
opt_critic1 = torch.optim.Adam(critic1.parameters(), lr=3e-4)
opt_critic2 = torch.optim.Adam(critic2.parameters(), lr=3e-4)

# %% [markdown]
# ## Вычисление целевого значения для критика

# %% [markdown]
# Отличия от **TD3**:
#
# 1. Используем двух критиков (берём минимум из их значений):
# $$V(s') = \min_{i = 1, 2} \left\{Q^{-}_i(s', a')\right\},$$
# где $a'$ &mdash; это сэмпл из целевой политики $\pi(a' \mid s')$;
# 2. Добавляется энтропийный бонус:
# $$V(s') = \min_{i = 1, 2} \left\{Q^{-}_i(s', a')\right\} - \alpha \log \pi(a' \mid s').$$

# %% [markdown]
# <span style="color: green"> __(0.5 балла)__ </span>

# %%
def compute_critic_target(rewards, next_states, is_done, actor, target_critic1, target_critic2,
                          gamma=0.99, alpha=0.4):
    '''
    Подсчет loss для критика.
    
    Параметры
        ----------
        rewards: torch.tensor [batch_size]
        next_states: torch.tensor [batch_size x features]
        is_done: torch.tensor [batch_size]
        gamma: float
        alpha: float
        
    Возвращает
        -------
        critic_target: torch.tensor [batch_size]
    '''
    with torch.no_grad():
        
        ### Ваш код
        next_actions, next_log_prob = actor.apply(next_states)
        target_q1 = target_critic1.get_qvalues(next_states, next_actions)
        target_q2 = target_critic2.get_qvalues(next_states, next_actions)
        next_values = torch.min(target_q1, target_q2) - alpha * next_log_prob
        critic_target = rewards + gamma * (1 - is_done) * next_values
        ###
    
    return critic_target

# %% [markdown]
# Отличия от **TD3**:
#
# Добавляется регуляризатор энтропии, чтобы стимулировать стохастичность политики:
# $$\mathbb{E}_{a \sim \pi(a \mid s)} \left[Q(s, a) - \alpha \log \pi(a \mid s)\right] \to \max_{\pi}$$

# %% [markdown]
# <span style="color: green"> __(0.5 балла)__ </span>

# %%
def compute_actor_loss(states, actor, critic1, alpha=0.4):
    '''
    Подсчет loss для актора.
    
    
    Параметры
        ----------
        states: torch.tensor [batch_size x features]
        alpha: float
        
    Возвращает
        -------
        actor_loss: torch.tensor [batch_size]
    '''
    ### Ваш код
    actions, log_prob = actor.apply(states)
    qvalues = critic1.get_qvalues(states, actions)
    actor_loss = alpha * log_prob - qvalues
    ###
    
    return actor_loss

# %% [markdown]
# # Пайплайн

# %% [markdown]
# Цель &mdash; достичь в среднем хотя бы **250 награды**.

# %%
seed = 162 # Иногда может сильно не повезти
np.random.seed(seed)
torch.manual_seed(seed)

# %%
# %load_ext tensorboard
# %tensorboard --logdir logs

# %%
def run_SAC(env, exp_replay, actor, target_actor, critic1, target_critic1, critic2, target_critic2,
            max_grad_norm=10, n_iter_max=1000000, timesteps_per_epoch=1, start_timesteps = 5000,
            batch_size=128, policy_update_freq=2, gamma=0.99, tau=0.005, alpha=0.1):
    
    interaction_state, _ = env.reset()
    random_actor = RandomActor()
    
    for n_iterations in trange(0, n_iter_max, timesteps_per_epoch):
        
        if len(exp_replay) < start_timesteps:
            _, interaction_state = play_and_record(interaction_state, random_actor, env,
                                                   exp_replay, timesteps_per_epoch)
            continue

        _, interaction_state = play_and_record(interaction_state, actor, env, exp_replay, timesteps_per_epoch)

        states, actions, rewards, next_states, is_done = exp_replay.sample_random(batch_size)

        states = torch.tensor(states, device=DEVICE, dtype=torch.float)
        actions = torch.tensor(actions, device=DEVICE, dtype=torch.float)
        rewards = torch.tensor(rewards, device=DEVICE, dtype=torch.float)
        next_states = torch.tensor(next_states, device=DEVICE, dtype=torch.float)
        is_done = torch.tensor(is_done.astype('float32'), device=DEVICE, dtype=torch.float)
        
        ### Ваш код
        critic_target = compute_critic_target(rewards, next_states, is_done, actor, target_critic1, target_critic2, gamma, alpha)
        critic1_loss = (critic1.get_qvalues(states, actions) - critic_target) ** 2
        ###
        optimize("critic1", critic1, opt_critic1, critic1_loss, n_iterations, max_grad_norm)
        
        ### Ваш код
        critic2_loss = (critic2.get_qvalues(states, actions) - critic_target) ** 2
        ###
        optimize("critic2", critic2, opt_critic2, critic2_loss, n_iterations, max_grad_norm)

        if n_iterations % policy_update_freq == 0:
            ### Ваш код
            actor_loss = compute_actor_loss(states, actor, critic1, alpha)
            ###
            optimize("actor", actor, opt_actor, actor_loss, n_iterations, max_grad_norm)

            update_target_networks(critic1, target_critic1, tau)
            update_target_networks(critic2, target_critic2, tau)

# %%
run_SAC(env, exp_replay, actor, target_actor, critic1, target_critic1, critic2, target_critic2)

# %% [markdown]
# ## Оценка

# %% [markdown]
# <span style="color: green"> __(1.5 балла)__ </span>

# %%
sessions = evaluate(env, actor, n_games=20)
score = sessions.mean()
print(f"Ваша награда: {score}")

assert score >= 250, "Нужно больше учить?"
print("Отлично!")

# %% [markdown]
# ## Запись

# %%
with RecordVideo(
    env = gym.make("BipedalWalker-v3", render_mode="rgb_array"),
    video_folder="./videos_SAC"
) as env_monitor:
    evaluate(env_monitor, actor, n_games=1, t_max=300)

# %%
video_paths = sorted([s for s in Path('videos_SAC').iterdir() if s.suffix == '.mp4'])
video_path = video_paths[-1]

data_url = str(video_path)

HTML("""
<video width="640" height="480" controls>
  <source src="{}" type="video/mp4">
</video>
""".format(data_url))

# %% [markdown]
# # Бонусное задание

# %% [markdown]
# <span style="color: green"> __(5 баллов)__ </span> Выбить хотя бы **300 награды** в режиме хардкора.

# %%
env = gym.make("BipedalWalker-v3", hardcore=True, render_mode="rgb_array")
env = Summaries(env, "Hard")

# %%
### Ваше решение
max_buffer_size = 10**5
exp_replay = ReplayBuffer(max_buffer_size)

actor = SAC_Actor(state_dim, action_dim, DEVICE).to(DEVICE)
critic1 = Critic(state_dim, action_dim).to(DEVICE)
critic2 = Critic(state_dim, action_dim).to(DEVICE)

target_critic1 = Critic(state_dim, action_dim).to(DEVICE)
target_critic2 = Critic(state_dim, action_dim).to(DEVICE)

target_critic1.load_state_dict(critic1.state_dict())
target_critic2.load_state_dict(critic2.state_dict())

target_actor = None
opt_actor = torch.optim.Adam(actor.parameters(), lr=3e-4)
opt_critic1 = torch.optim.Adam(critic1.parameters(), lr=3e-4)
opt_critic2 = torch.optim.Adam(critic2.parameters(), lr=3e-4)

run_SAC(env, exp_replay, actor, target_actor, critic1, target_critic1, critic2, target_critic2,
        n_iter_max=1500000, start_timesteps=10000, alpha=0.1)

sessions = evaluate(env, actor, n_games=20)
score = sessions.mean()
print(f"Ваша награда в hardcore: {score}")
